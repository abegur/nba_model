# %%
import pandas as pd
import numpy as np
from sklearn import linear_model, tree

# %%
from nba_api.stats.endpoints import playergamelog

steven_games = playergamelog.PlayerGameLog(player_id = '203500')
steven_games_df = steven_games.get_data_frames()
# print(steven_games_df)
# game ID -> 0021900949
# get the file path on the api 
# simply just change the '/' to '.' and find what file you want
# then open the file and see what functions they have       
# example:
# nba_api/stats/endpoints/boxscoredefensive.py 

from nba_api.stats.endpoints import boxscoredefensive
# if you look in this class game_id is the only not default class need to set it. 
bx = boxscoredefensive.BoxScoreDefensive(game_id = '0021900949')
bx_df = bx.get_data_frames()[0]
# print("defensive stats",bx_df )
bx_df
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION      TEAM_CITY TEAM_NICKNAME  \
# 0   0021900949  1610612760               OKC  Oklahoma City       Thunder
# 1   0021900949  1610612760               OKC  Oklahoma City       Thunder
# 2   0021900949  1610612760               OKC  Oklahoma City       Thunder
# 3   0021900949  1610612760               OKC  Oklahoma City       Thunder
# 4   0021900949  1610612760               OKC  Oklahoma City       Thunder
# 5   0021900949  1610612760               OKC  Oklahoma City       Thunder
# 6   0021900949  1610612760               OKC  Oklahoma City       Thunder
# 7   0021900949  1610612760               OKC  Oklahoma City       Thunder
# 8   0021900949  1610612760               OKC  Oklahoma City       Thunder
# 9   0021900949  1610612738               BOS         Boston       Celtics
# 10  0021900949  1610612738               BOS         Boston       Celtics
# 11  0021900949  1610612738               BOS         Boston       Celtics
# 12  0021900949  1610612738               BOS         Boston       Celtics
# 13  0021900949  1610612738               BOS         Boston       Celtics
# 14  0021900949  1610612738               BOS         Boston       Celtics
# 15  0021900949  1610612738               BOS         Boston       Celtics
# 16  0021900949  1610612738               BOS         Boston       Celtics
# 17  0021900949  1610612738               BOS         Boston       Celtics
# 18  0021900949  1610612738               BOS         Boston       Celtics
# 19  0021900949  1610612738               BOS         Boston       Celtics
#
#     PLAYER_ID          PLAYER_NAME START_POSITION COMMENT MATCHUP_MIN  ...  \
# 0     1628390    Terrance Ferguson              F                6:58  ...
# 1      201568     Danilo Gallinari              F               11:11  ...
# 2      203500         Steven Adams              C                9:14  ...
# 3     1629652        Luguentz Dort              G               10:18  ...
# 4      101108           Chris Paul              G               13:06  ...
# 5      203457         Nerlens Noel                               7:09  ...
# 6     1628977       Hamidou Diallo                               6:13  ...
# 7      203471      Dennis Schroder                              11:35  ...
# 8     1627846          Abdel Nader                               6:11  ...
# 9      202330       Gordon Hayward              F               12:55  ...
# 10    1628369         Jayson Tatum              F               12:57  ...
# 11    1628464         Daniel Theis              C               10:02  ...
# 12     203935         Marcus Smart              G               13:31  ...
# 13     202689         Kemba Walker              G               10:40  ...
# 14     202954       Brad Wanamaker                               3:25  ...
# 15     202683          Enes Kanter                               2:00  ...
# 16    1628400         Semi Ojeleye                               1:20  ...
# 17    1629641       Romeo Langford                               7:00  ...
# 18    1629684       Grant Williams                               4:47  ...
# 19    1629057  Robert Williams III                               4:37  ...
#
#     MATCHUP_AST  MATCHUP_TOV  STL  BLK  MATCHUP_FGM  MATCHUP_FGA  \
# 0             3            1    1    0            4           13
# 1             4            1    0    0            3           11
# 2             1            2    3    1            3            7
# 3             0            5    2    1            3            7
# 4             1            0    1    1            8           16
# 5             3            3    0    0            7           11
# 6             2            0    0    0            3           10
# 7             3            0    2    0            4            8
# 8             0            1    0    4            2            8
# 9             1            2    1    2            3           13
# 10            3            2    2    1            4            8
# 11            2            3    0    0            8           12
# 12            1            1    0    0            9           13
# 13            3            2    2    0            4           12
# 14            0            1    1    0            2            7
# 15            0            0    0    0            0            0
# 16            1            0    0    0            0            0
# 17            2            1    1    0            2            3
# 18            1            1    1    1            1            3
# 19            0            1    1    1            2            8
#
#     MATCHUP_FG_PCT  MATCHUP_FG3M  MATCHUP_FG3A  MATCHUP_FG3_PCT
# 0            0.308             2             6            0.333
# 1            0.273             1             6            0.167
# 2            0.429             1             2            0.500
# 3            0.429             0             3            0.000
# 4            0.500             4             7            0.571
# 5            0.636             3             6            0.500
# 6            0.300             1             3            0.333
# 7            0.500             1             3            0.333
# 8            0.250             0             1            0.000
# 9            0.231             0             3            0.000
# 10           0.500             2             4            0.500
# 11           0.667             0             0            0.000
# 12           0.692             4             4            1.000
# 13           0.333             3             6            0.500
# 14           0.286             0             4            0.000
# 15           0.000             0             0            0.000
# 16           0.000             0             0            0.000
# 17           0.667             1             2            0.500
# 18           0.333             0             1            0.000
# 19           0.250             0             1            0.000
#
# [20 rows x 24 columns]

# %%
from nba_api.stats.static import players
player_data = players.get_active_players()
print(player_data[:3])
# Out:
# [{'id': 203500, 'full_name': 'Steven Adams', 'first_name': 'Steven', 'last_name': 'Adams', 'is_active': True}, {'id': 1628389, 'full_name': 'Bam Adebayo', 'first_name': 'Bam', 'last_name': 'Adebayo', 'is_active': True}, {'id': 200746, 'full_name': 'LaMarcus Aldridge', 'first_name': 'LaMarcus', 'last_name': 'Aldridge', 'is_active': True}]

# %%
from nba_api.stats.endpoints import boxscoresummaryv2
knicks_okc = boxscoresummaryv2.BoxScoreSummaryV2(game_id = '0021900932')
df = knicks_okc.get_data_frames()[0]
df
# print(df[:])
#0021900932
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2020-03-06T00:00:00              3  0021900932               3
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0            Final  20200306/OKCNYK    1610612752       1610612760   2019
#
#    LIVE_PERIOD LIVE_PC_TIME NATL_TV_BROADCASTER_ABBREVIATION  \
# 0            4                                          None
#
#   LIVE_PERIOD_TIME_BCAST  WH_STATUS
# 0            Q4       -           1
